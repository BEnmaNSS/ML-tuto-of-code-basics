# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
from sklearn import linear_model

# %%
df = pd.read_csv("homeprices.csv")
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
# Scatter plot
plt.scatter(df['area'], df['price'], label='Scatter Plot')

# Plot the regression line
plt.plot(df['area'], reg.predict(df[['area']]), color='red', label='Regression Line')

# Add labels and legend
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Scatter Plot with Regression Line')
plt.legend()

# Show the plot
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price )
# Out:
# LinearRegression()

# %% [markdown]
# The outer list [...] corresponds to different samples (rows), and the inner list [3300] corresponds to the features (columns).
# In this case, there is only one sample (outer list) with one feature (inner list). So, it's like having a dataset with one row and one column.

# %%
reg.predict([[3300]])
# Out:
# C:\Users\youne\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %% [markdown]
# We have our linear model in the format: \(y = mx + b\).
#
# - \(y\): Prices
# - \(m\): Slope
# - \(b\): Intercept
# - \(x\): Our number

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
#now we are applying the calculation (price = m*area + price).
135.78767123*3300 + 180616.43835616432
#the result is the same array as it is.
# Out:
# 628715.7534151643

# %% [markdown]
# lest's say that we have data for prediction and now we are using it for the prediction

# %%
area = pd.read_csv('areas.csv')
area.head(3)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300

# %%
p = reg.predict(area)

# %%
area['predicted prices'] = p 
area
# Out:
#     area  predicted prices
# 0   1000      3.164041e+05
# 1   1500      3.842979e+05
# 2   2300      4.929281e+05
# 3   3540      6.613048e+05
# 4   4120      7.400616e+05
# 5   4560      7.998082e+05
# 6   5490      9.260908e+05
# 7   3460      6.504418e+05
# 8   4750      8.256079e+05
# 9   2300      4.929281e+05
# 10  9000      1.402705e+06
# 11  8600      1.348390e+06
# 12  7100      1.144709e+06

# %%
area.to_csv("prediction.csv",index=False)
