# %%
from IPython import display

# Display the image from a local file
display.Image("C:\\Users\\youne\\Pictures\\Screenshots\\Screenshot 2024-01-04 083040.png")

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('C:\\Users\\youne\\Downloads\\HR_comma_sep.csv')
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %% [markdown]
# #Data exploration and visualization

# %%
left_counts = df['left'].value_counts()
print(left_counts)
# Out:
# left
# 0    11428
# 1     3571
# Name: count, dtype: int64

# %%
#there is no missing values
df['left'].isnull().sum()
# Out:
# 0

# %%
unique_left_values = df['left'].unique()
print(unique_left_values)
# Out:
# [1 0]

# %%
left = df[df.left==1]
left.shape
# Out:
# (3571, 10)

# %%
retained = df[df.left==0]
retained.shape
# Out:
# (11428, 10)

# %%
df.groupby('left').sum()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0                7620.30          8176.43           43274
# 1                1571.59          2564.38           13768
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0                  2274860               38627           2000
# 1                   740694               13843            169
#
#       promotion_last_5years  \
# left
# 0                       300
# 1                        19
#
#                                              Department  \
# left
# 0     salessalessalessalessalessalessalessalessaless...
# 1     salessalessalessalessalessalessalessalessaless...
#
#                                                  salary
# left
# 0     lowlowlowlowlowlowlowlowlowlowmediummediummedi...
# 1     lowmediummediumlowlowlowlowlowlowlowlowlowlowl...

# %% [markdown]
# From above table we can draw following conclusions,
# <ol>
#     <li>**Satisfaction Level**: Satisfaction level seems to be relatively low (0.44) in employees leaving the firm vs the retained ones (0.66)</li>
#     <li>**Average Monthly Hours**: Average monthly hours are higher in employees leaving the firm (199 vs 207)</li>
#     <li>**Promotion Last 5 Years**: Employees who are given promotion are likely to be retained at firm </li>
# </ol>

# %%
pd.crosstab(df.salary,df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='salary'>

# %%
cross_tab.plot(kind='bar', stacked=False)
plt.show()

# %%
cross_tab = pd.crosstab(df['Department'], df['left'])
cross_tab.plot(kind='bar', stacked=False)
plt.show()

# %%
sns.histplot(data=df, x='satisfaction_level', kde=True)

plt.show()

# %%
data = df['promotion_last_5years'].value_counts()

# Define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:len(data)]

# Create pie chart
plt.pie(data, labels = data.index, colors = colors, autopct='%.0f%%')
plt.show()

# %% [markdown]
# <h3 style="color:purple">From the data analysis so far we can conclude that we will use following variables as independant variables in our model</h3>
# <ol>
#     <li>**Satisfaction Level**</li>
#     <li>**Average Monthly Hours**</li>
#     <li>**Promotion Last 5 Years**</li>
#     <li>**Salary**</li>
# </ol>

# %%
subdf = df[['satisfaction_level','average_montly_hours','promotion_last_5years','salary']]
subdf.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                0.38                   157                      0       1
# 1                0.80                   262                      0       2
# 2                0.11                   272                      0       2
# 3                0.72                   223                      0       1
# 4                0.37                   159                      0       1

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['salary'] = le.fit_transform(df['salary'])

# %%
df['salary']
# Out:
# 0        1
# 1        2
# 2        2
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: salary, Length: 14999, dtype: int64

# %%
subdf
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                    0.38                   157                      0       1
# 1                    0.80                   262                      0       2
# 2                    0.11                   272                      0       2
# 3                    0.72                   223                      0       1
# 4                    0.37                   159                      0       1
# ...                   ...                   ...                    ...     ...
# 14994                0.40                   151                      0       1
# 14995                0.37                   160                      0       1
# 14996                0.37                   143                      0       1
# 14997                0.11                   280                      0       1
# 14998                0.37                   158                      0       1
#
# ...

# %%
X = subdf[['satisfaction_level', 'average_montly_hours', 'promotion_last_5years']]
X
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
# [14999 rows x 3 columns]

# %%
y = df['left']
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %% [markdown]
# # splitting the data

# %%
from  sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# # model accuracy

# %%
import pandas as pd

predictions = model.predict(X_test)
predictions_df = pd.DataFrame(predictions, columns=['Prediction'])
print(predictions_df)
# Out:
#       Prediction
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 2995           0
# 2996           0
# 2997           0
# 2998           0
# 2999           0
#
# [3000 rows x 1 columns]

# %%
h = predictions_df['Prediction'].value_counts()
h
# Out:
# Prediction
# 0    2668
# 1     332
# Name: count, dtype: int64

# %%
predictions = model.predict([[0.,50,0]])

# Print the predictions
print(predictions)
# Out:
# [1]
# C:\Users\youne\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
model.score (X_test,y_test)
# Out:
# 0.7716666666666666
