# %%
from IPython.display import Image, display

# Replace backslashes with forward slashes in the file path
image_path = 'C:/Users/youne/Pictures/Screenshots/Screenshot 2024-01-02 175403.png'

# Display the image
display(Image(filename=image_path))

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\youne\\Downloads\\carprices.csv')
df
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)
# 0                  BMW X5    69000          18000         6
# 1                  BMW X5    35000          34000         3
# 2                  BMW X5    57000          26100         5
# 3                  BMW X5    22500          40000         2
# 4                  BMW X5    46000          31500         4
# 5                 Audi A5    59000          29400         5
# 6                 Audi A5    52000          32000         5
# 7                 Audi A5    72000          19300         6
# 8                 Audi A5    91000          12000         8
# 9   Mercedez Benz C class    67000          22000         6
# 10  Mercedez Benz C class    83000          20000         7
# 11  Mercedez Benz C class    79000          21000         7
# 12  Mercedez Benz C class    59000          33000         5

# %%
dfle = df

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dfle = df
dfle['Car Model']= le.fit_transform(dfle['Car Model'])
dfle
# Out:
#     Car Model  Mileage  Sell Price($)  Age(yrs)
# 0           1    69000              1         6
# 1           1    35000             11         3
# 2           1    57000              6         5
# 3           1    22500             12         2
# 4           1    46000              8         4
# 5           0    59000              7         5
# 6           0    52000              9         5
# 7           0    72000              2         6
# 8           0    91000              0         8
# 9           2    67000              5         6
# 10          2    83000              3         7
# 11          2    79000              4         7
# 12          2    59000             10         5

# %%
X = dfle[['Car Model','Mileage','Age(yrs)']]
X
# Out:
#     Car Model  Mileage  Age(yrs)
# 0           1    69000         6
# 1           1    35000         3
# 2           1    57000         5
# 3           1    22500         2
# 4           1    46000         4
# 5           0    59000         5
# 6           0    52000         5
# 7           0    72000         6
# 8           0    91000         8
# 9           2    67000         6
# 10          2    83000         7
# 11          2    79000         7
# 12          2    59000         5

# %%
y = dfle['Sell Price($)']
y
# Out:
# 0      1
# 1     11
# 2      6
# 3     12
# 4      8
# 5      7
# 6      9
# 7      2
# 8      0
# 9      5
# 10     3
# 11     4
# 12    10
# Name: Sell Price($), dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict(X) # 2600 sqr ft home in new jersey
# Out:
# array([ 4.50503246, 10.62301575,  6.75019415, 13.02255289,  8.68660495,
#         5.27485943,  7.43611568,  2.72094685, -0.22562207,  5.98036718,
#         2.50020192,  3.73520549,  6.9905253 ])

# %%
model.predict([[2,45000,4]])
# Out:
# C:\Users\youne\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([9.85318878])

# %%
model.score(X,y)
# Out:
# 0.8305621563053766
